# %% [markdown]
# # Generando muestras aleatorias de una $N_p$
# <img src="https://raw.githubusercontent.com/fhernanb/fhernanb.github.io/master/docs/logo_unal_color.png" alt="drawing" width="200"/>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Simulando de una $N_2(\boldsymbol{\mu}, \boldsymbol{\Sigma})$

# %% [markdown]
# El vector de medias y la matriz de covarianzas a usar:

# %%
mean = [0, 0]             # a vector
cov = [[2, -2], [-2, 3]]  # a matrix

# %% [markdown]
# Para verificar los valores ingresados

# %%
print(mean)
print(cov)
# Out:
# [0, 0]
# [[2, -2], [-2, 3]]

# %% [markdown]
# Para simular se usa la función `random.multivariate_normal`, a continuación vamos a simular 500 observaciones.

# %%
x, y = np.random.multivariate_normal(mean, cov, size=500).T

# %% [markdown]
# Para crear el diagrama de dispersión se usa la siguiente instrucción.

# %%
plt.plot(x, y, 'x', color='blue')

# %% [markdown]
# Para dibujar una matriz con diagramas de dispersión se usa lo siguiente

# %%
d = {'x': x, 'y': y}
df = pd.DataFrame(data=d)
pd.plotting.scatter_matrix(df, color='red')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000012272CE54A8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001227306DD30>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000122730A6D30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000122730DDC88>]],
#       dtype=object)

# %% [markdown]
# ## Simulando de una $N_3(\boldsymbol{\mu}, \boldsymbol{\Sigma})$
#
# El vector de medias y la matriz de covarianzas a usar:

# %%
mean = [2, -3, 1]                        # a vector
cov = [[1, 1, 1], [1, 3, 2], [1, 2, 2]]  # a matrix

# %% [markdown]
# Para simular se usa la función `random.multivariate_normal`, a continuación vamos a simular 500 observaciones.

# %%
x, y, z = np.random.multivariate_normal(mean, cov, size=500).T

# %% [markdown]
# Para dibujar una matriz con diagramas de dispersión se usa lo siguiente

# %%
d = {'x': x, 'y': y, 'z': z}
df = pd.DataFrame(data=d)
pd.plotting.scatter_matrix(df, color='orange')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000012273078F28>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000122732001D0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000122732390F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x00000122732730B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000122732AC0B8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x00000122732AC0F0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001227330DC18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x0000012273353128>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001227338B668>]],
#       dtype=object)
