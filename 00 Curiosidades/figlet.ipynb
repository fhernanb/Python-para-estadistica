# %% [markdown]
# # Creación de mensaje figlet
#
# <img src="https://raw.githubusercontent.com/fhernanb/fhernanb.github.io/master/my_docs/logo_unal_color.png" alt="drawing" width="200"/>
#
# En este documento se muestra como escribir mensajes en tipo figlet.
#
# Lo primero es instalar los paquetes pyfigles y colorama.

# %%
# !pip install pyfiglet
# !pip install colorama

# %%
from colorama import Fore
import pyfiglet

# %% [markdown]
# # Ejemplo 1

# %%
mensaje = pyfiglet.figlet_format("Soy Freddy")
print(Fore.BLUE + mensaje)
# Out:
#  ____                _____             _     _
# / ___|  ___  _   _  |  ___| __ ___  __| | __| |_   _
# \___ \ / _ \| | | | | |_ | '__/ _ \/ _` |/ _` | | | |
#  ___) | (_) | |_| | |  _|| | |  __/ (_| | (_| | |_| |
# |____/ \___/ \__, | |_|  |_|  \___|\__,_|\__,_|\__, |
#              |___/                             |___/

# %% [markdown]
# # Ejemplo 2

# %%
mensaje = pyfiglet.figlet_format("hOLA mundo")
print(Fore.MAGENTA + mensaje)
# Out:
#  _      ___  _        _                                _
# | |__  / _ \| |      / \     _ __ ___  _   _ _ __   __| | ___
# | '_ \| | | | |     / _ \   | '_ ` _ \| | | | '_ \ / _` |/ _ \
# | | | | |_| | |___ / ___ \  | | | | | | |_| | | | | (_| | (_) |
# |_| |_|\___/|_____/_/   \_\ |_| |_| |_|\__,_|_| |_|\__,_|\___/
