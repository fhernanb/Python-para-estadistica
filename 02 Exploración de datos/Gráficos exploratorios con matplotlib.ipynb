# %% [markdown]
# # Gráficos exploratorios con `matplotlib`
# <img src="https://raw.githubusercontent.com/fhernanb/fhernanb.github.io/master/docs/logo_unal_color.png" alt="drawing" width="200"/>
# <br>
# En esta lección se mostrará como usar `matplotlib` para crear gráficos con el objetivo de explorar una base de datos.
#
# A continuación las librerías necesarias para realizar los ejemplos.

# %%
import pandas as pd
import matplotlib as mp
import matplotlib.pyplot as plt
from scipy import stats

# %% [markdown]
# ## Leyendo los datos del ejemplo
#
# Para el ejemplo vamos a usar la base de datos sobre apartamentos usados en la ciudad de Medellín, la base de datos está disponible en [este enlace](https://raw.githubusercontent.com/fhernanb/datos/master/aptos2015). Para leer la base de datos usamos las siguientes instrucciones.

# %%
url = 'https://raw.githubusercontent.com/fhernanb/datos/master/aptos2015'
dt = pd.read_table(url, comment='#', sep=' ')
dt.head()
# Out:
#    precio    mt2 ubicacion  estrato  alcobas  banos balcon parqueadero  \
# 1    79.0  43.16     norte        3        3      1     si          si
# 2    93.0  56.92     norte        2        2      1     si          si
# 3   100.0  66.40     norte        3        2      2     no          no
# 4   123.0  61.85     norte        2        3      2     si          si
# 5   135.0  89.80     norte        4        3      2     si          no
#
#    administracion     avaluo terminado
# 1           0.050  14.923002        no
# 2           0.069  27.000000        si
# 3           0.000  15.738427        no
# 4           0.130  27.000000        no
# 5           0.000  39.567000        si

# %% [markdown]
# ## Histograma y densidad
# Para crear un histograma se usa la función `hist`, la documentación completa de la función se puede consultar este [enlace](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.hist.html).
#
# A continuación el histograma para la variable `precio` usando 10 intervalos.

# %%
plt.hist(dt.precio, bins=10, facecolor='salmon', edgecolor='black')
plt.xlabel('Precio (millones $)')
plt.ylabel('Frecuencia absoluta')
plt.title('Histograma para Precio')
plt.grid(True)

# %% [markdown]
# Para crear el mismo histograma pero con frecuencia relativa se usa el siguiente código.

# %%
plt.hist(dt.precio, bins=10, facecolor='lightblue', edgecolor='black', density=True)
plt.xlabel('Precio (millones $)')
plt.ylabel('Frecuencia relativa')
plt.title('Histograma para Precio');

# %% [markdown]
# Para dibujar una densidad se usa `plot`, la documentación completa de la función se puede consultar este [enlace](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.plot.html).
#
# A continuación la densidad para la variable `precio`.

# %%
dt.precio.plot(kind='density', color='orange', linewidth=5.5)
plt.xlabel('Precio (millones $)')
plt.ylabel('Densidad')
plt.xlim(-100, 1750)
plt.title('Densidad para Precio');

# %% [markdown]
# ## Diagrama de dispersión
#
# Para crear un diagrama de dispersión se usa la función `scatter`, la documentación completa de la función se puede consultar este [enlace](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.scatter.html).
#
# A continuación el diagrama de dispersión para las variable `precio` y `mt2`.

# %%
plt.scatter(x=dt.precio, y=dt.mt2, color='purple', alpha=0.15)
plt.xlabel('Precio (millones $)')
plt.ylabel('Área (m2)')
plt.title('Diagrama de dispersión con 2 variables');

# %% [markdown]
# Es posible incluir otra variable cuantitativa en el diagrama de dispersión por medio del parámetro `s` para modificar el tamaño de la burbuja, abajo el código para incluir el valor de avaluo en el diagrama.

# %%
plt.scatter(x=dt.precio, y=dt.mt2, alpha=0.15, color='tomato', s=dt.avaluo*0.5)
plt.xlabel('Precio (millones $)')
plt.title('Diagrama de dispersión con 3 variables')
plt.ylabel('Área (m2)');

# %% [markdown]
# Es posible incluir otra variable para diferenciar por color por medio del parámetro `c`, abajo el código para incluir la variable número de baños en el diagrama.

# %%
plt.scatter(x=dt.precio, y=dt.mt2, alpha=0.5, c=dt.banos)
plt.xlabel('Precio (millones $)')
plt.ylabel('Área (m2)')
plt.title('Diagrama de dispersión con 3 variables')
plt.colorbar();

# %% [markdown]
# Los dos tipos de diagramas de dispersión pueden ser unificados en uno solo, abajo el código para hacerlo.

# %%
plt.scatter(x=dt.precio, y=dt.mt2, alpha=0.5, s=dt.avaluo*0.5, c=dt.banos)
plt.xlabel('Precio (millones $)')
plt.ylabel('Área (m2)')
plt.title('Diagrama de dispersión con 4 variables')
plt.colorbar();

# %% [markdown]
# ## Histogramas en dos dimensiones
#
# Para dibujar histogramas en dos dimensiones se puede usar la función `hist2d`, la documentación completa de la función se puede consultar este [enlace](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.hist2d.html).
#
# A continuación el histograma 2d para las variable `precio` y `mt2`.

# %%
plt.hist2d(x=dt.precio, y=dt.mt2, bins=(20, 20))
plt.xlabel('Precio (millones $)')
plt.ylabel('Área (m2)')
plt.show()
